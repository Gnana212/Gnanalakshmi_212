# %%
def reg():
    print("SIGN UP")
    user = input("enter your username")
    user1 = r"^[a-zA-Z0-9-_]+@[a-zA-Z0-9]+\.[a-z]{1,3}$"
 
    if (re.match(user1,user)):
        password = input("enter your password")
    
        pass1 = "^(?=.*[a-z])(?=.*[A-Z])(?=.*\d)(?=.*[@$!%*#?&])[A-Za-z\d@$!#%*?&]{5,16}$"
        if (re.match(pass1,password)):
               
            print("suucessfully signed up")
            file = open ('task.txt','a')
            file.write(user+" "+password+"\n")
            file.close()
        else:
            print("invalid.please try again")
            print("\nMaximum length for password (5 to 16)\nPassword must contains one Uppercase and one Lower case letters\nPassword must conatins one special character\nPassword must contains one number\n")
            reg()
    else:
        print("Please enter valid username")
        print("Invalid username ")
        reg()
        
def log():
    print("SIGN IN")
    username = input("enter your username")
    
    password = input('enter your password')
    with open('task.txt') as fp:
        contents = fp.read()
        status=0
        if username in contents:
            if password in contents:
                print("logged on")
                det()
            else:
                print("incorrect password")
            
       
     
       
        else:
            print("username not found.please register")
       
   
 
def det():
    print(" press 1 for login and 2 for signup and 3 for exit")
    de=int(input("Please enter the option : "))
    if de == 1:
        log()
        det()
    elif de ==2:
        reg()
        det()
    elif de ==3:
        print("thank you")
    else:
        print("please enter 1 or 2")
        det()
        
import re
det()
# Out:
#  press 1 for login and 2 for signup and 3 for exit
# Please enter the option : 1
# SIGN IN
# enter your usernamegnanar22@gmail.com
# enter your passwordgnana212@$
# logged on
#  press 1 for login and 2 for signup and 3 for exit
# Please enter the option : 2
# SIGN UP
# enter your usernameteddyrg@gmail.com
# enter your passwordrg@$R212
# suucessfully signed up
#  press 1 for login and 2 for signup and 3 for exit
# Please enter the option : 3
# thank you
#  press 1 for login and 2 for signup and 3 for exit
